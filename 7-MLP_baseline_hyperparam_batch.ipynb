# %% [markdown]
# # MLP FROM BASELINE WITH HYPERPARAMETER TUNING
#  Goal: optimise Cox partial likelihood loss and maximise C-index score in validation.
#
# Main changes:
# LR sweep: controls stability and speed of convergence
#     - too high: loss unstable, C-index fluctuates
#     - too low: undertraining, slow plateau

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import (
    accuracy_score, balanced_accuracy_score,
    classification_report, confusion_matrix
) 

import tensorflow as tf
from tensorflow import keras
from keras import layers


RANDOM_STATE = 42
tf.random.set_seed(RANDOM_STATE)
np.random.seed(RANDOM_STATE)

# %% [markdown]
# ## Charger les X_train/ X_test…

# %%
X_train = np.load("./tcga_brca_qc_report/X_train_z.npy")
X_test  = np.load("./tcga_brca_qc_report/X_test_z.npy")

# tf/keras: float32 recommandé
X_train = np.asarray(X_train, dtype=np.float32)
X_test  = np.asarray(X_test, dtype=np.float32)

print("X_train:", X_train.shape, X_train.dtype)
print("X_test :", X_test.shape,  X_test.dtype)
# Out:
# X_train: (814, 10000) float32
# X_test : (208, 10000) float32

# %% [markdown]
# # Charger les méta et définir les colonnes de survie

# %%
""" temps: days_to_last follow_up or days_to_death
event: vital_status (dead or alive)
"""

meta_tr = pd.read_csv("./tcga_brca_qc_report/meta_train_postQC.csv")
meta_te = pd.read_csv("./tcga_brca_qc_report/meta_test_postQC.csv")

# 
# temps (en jours) et event (dead or alive)
TIME_COL = "days_to_last_follow_up"    # car days_to_death a bcp trop de NaN
EVENT_COL = "vital_status"  

if TIME_COL not in meta_tr.columns or EVENT_COL not in meta_tr.columns:
    raise ValueError(
        f"TIME_COL/EVENT_COL non trouvées dans meta.\n"
        f"Colonnes meta_tr (extrait): {meta_tr.columns.tolist()[:40]}"
    )

t_train = pd.to_numeric(meta_tr[TIME_COL], errors="coerce").values
e_train = pd.to_numeric(meta_tr[EVENT_COL], errors="coerce").values

t_test  = pd.to_numeric(meta_te[TIME_COL], errors="coerce").values
e_test  = pd.to_numeric(meta_te[EVENT_COL], errors="coerce").values

print("Survival train:", np.nanmin(t_train), np.nanmax(t_train), "events:", np.nansum(e_train))
print("Survival test :", np.nanmin(t_test),  np.nanmax(t_test),  "events:", np.nansum(e_test))
# Out:
# Survival train: -7.0 8605.0 events: 0.0
# Survival test : 0.0 5156.0 events: 0.0

# %% [markdown]
# ## Standardiser vital_status et création de event (CoX°)

# %%
def standardize_vital_status(series):
    s = series.copy()

    # Cas numérique (0/1)
    s_num = pd.to_numeric(s, errors="coerce")
    vals = set(s_num.dropna().unique().tolist())
    if len(vals) > 0 and vals.issubset({0.0, 1.0}):
        return s_num

    # Cas texte ("Alive"/"Dead")
    s_txt = s.astype(str).str.strip().str.lower()
    return s_txt.map({"alive": 1, "dead": 0})


meta_tr["vital_status"] = standardize_vital_status(meta_tr["vital_status"])
meta_te["vital_status"] = standardize_vital_status(meta_te["vital_status"])

# Convention Cox : event = 1 si décès
meta_tr["event"] = 1 - meta_tr["vital_status"]
meta_te["event"] = 1 - meta_te["vital_status"]

print("vital_status train:")
print(meta_tr["vital_status"].value_counts(dropna=False))
print("vital_status test:")
print(meta_te["vital_status"].value_counts(dropna=False))
# Out:
# vital_status train:
# vital_status
# 1.0    694
# 0.0    119
# NaN      1
# Name: count, dtype: int64
# vital_status test:
# vital_status
# 1    186
# 0     22
# Name: count, dtype: int64

# %% [markdown]
# # Refaire l'alignement

# %%
TIME_COL = "days_to_last_follow_up"
EVENT_COL = "event"

time_tr  = pd.to_numeric(meta_tr[TIME_COL], errors="coerce")
event_tr = pd.to_numeric(meta_tr[EVENT_COL], errors="coerce")

mask_tr = time_tr.notna() & (time_tr > 0) & event_tr.notna() & event_tr.isin([0, 1])

X_train = X_train[mask_tr.values]
meta_tr = meta_tr.loc[mask_tr].reset_index(drop=True)

time_te  = pd.to_numeric(meta_te[TIME_COL], errors="coerce")
event_te = pd.to_numeric(meta_te[EVENT_COL], errors="coerce")

mask_te = time_te.notna() & (time_te > 0) & event_te.notna() & event_te.isin([0, 1])

X_test = X_test[mask_te.values]
meta_te = meta_te.loc[mask_te].reset_index(drop=True)

print("Aligned train:", X_train.shape, meta_tr.shape)
print("Aligned test :", X_test.shape, meta_te.shape)
# Out:
# Aligned train: (795, 10000) (795, 91)
# Aligned test : (206, 10000) (206, 91)

# %%
# Recréer t_test / e_test APRÈS alignement (sinon peut avoir mismatch)
# ============================================================

t_test = meta_te[TIME_COL].astype(np.float32).values
e_test = meta_te[EVENT_COL].astype(np.float32).values  # EVENT_COL = "event"

print("Shapes check -> X_test:", X_test.shape, " t_test:", t_test.shape, " e_test:", e_test.shape)
# Out:
# Shapes check -> X_test: (206, 10000)  t_test: (206,)  e_test: (206,)

# %%
# verifie le nombre de alive et dead après le mapping
print(meta_tr["vital_status"].value_counts(dropna=False))
print(meta_te["vital_status"].value_counts(dropna=False))
# Out:
# vital_status
# 1.0    678
# 0.0    117
# Name: count, dtype: int64
# vital_status
# 1    184
# 0     22
# Name: count, dtype: int64

# %% [markdown]
# # Checker les NaN

# %%
# Check combien de NaN dans event et time restent et si event est bien en binaire
print("NaN event train:", meta_tr["event"].isna().sum())
print("NaN event test :", meta_te["event"].isna().sum())

print("Unique event train:", meta_tr["event"].dropna().unique()[:10])
print("Unique event test :", meta_te["event"].dropna().unique()[:10])

print("NaN time train:", meta_tr["days_to_last_follow_up"].isna().sum())
print("NaN time test :", meta_te["days_to_last_follow_up"].isna().sum())
# Out:
# NaN event train: 0
# NaN event test : 0
# Unique event train: [0. 1.]
# Unique event test : [0 1]
# NaN time train: 0
# NaN time test : 0

# %%
assert meta_tr["event"].isna().sum() == 0
assert meta_te["event"].isna().sum() == 0
assert (meta_tr["days_to_last_follow_up"] > 0).all()
assert (meta_te["days_to_last_follow_up"] > 0).all()

print("Survival data clean and aligned ✔")
# Out:
# Survival data clean and aligned ✔

# %% [markdown]
# # Split intern /validation

# %%
val_frac = 0.15

n = X_train.shape[0]
idx = np.arange(n)
np.random.default_rng(RANDOM_STATE).shuffle(idx)

n_val = int(val_frac * n)
val_idx = idx[:n_val]
tr_idx  = idx[n_val:]

X_tr  = X_train[tr_idx]
X_val = X_train[val_idx]

t_tr  = meta_tr.iloc[tr_idx]["days_to_last_follow_up"].astype(np.float32).values
t_val = meta_tr.iloc[val_idx]["days_to_last_follow_up"].astype(np.float32).values

e_tr  = meta_tr.iloc[tr_idx]["event"].astype(np.float32).values
e_val = meta_tr.iloc[val_idx]["event"].astype(np.float32).values

print("Train:", X_tr.shape)
print("Val  :", X_val.shape)
print("Test :", X_test.shape)
print("Event rate (train):", e_tr.mean())
# Out:
# Train: (676, 10000)
# Val  : (119, 10000)
# Test : (206, 10000)
# Event rate (train): 0.147929

# %% [markdown]
# # Loss Cox partial likelihood

# %%
def cox_ph_loss(t, e, r, eps=1e-8):
    # shapes
    t = tf.reshape(tf.cast(t, tf.float32), [-1])
    e = tf.reshape(tf.cast(e, tf.float32), [-1])
    r = tf.reshape(tf.cast(r, tf.float32), [-1])

    # sort by descending time
    order = tf.argsort(t, direction="DESCENDING")
    e = tf.gather(e, order)
    r = tf.gather(r, order)

    # numeric stabilization: subtract max before exp, then add it back
    r_max = tf.reduce_max(r)
    r_stab = r - r_max

    # log(sum_{j in risk set} exp(r_j)) via log(cumsum(exp(.)))
    log_cum_sum_exp = tf.math.log(tf.cumsum(tf.exp(r_stab)) + eps) + r_max

    pll = tf.reduce_sum(e * (r - log_cum_sum_exp))
    n_events = tf.reduce_sum(e) + eps
    return -pll / n_events

# %% [markdown]
# # Sanity check

# %%
def _check_shapes(X, t, e, name):
    assert X.shape[0] == len(t) == len(e), f"{name}: mismatch shapes"
    assert np.isfinite(X).all(), f"{name}: X has NaN/inf"
    assert np.isfinite(t).all(), f"{name}: t has NaN/inf"
    assert np.isfinite(e).all(), f"{name}: e has NaN/inf"
    # e doit être binaire {0,1}
    u = set(np.unique(e).tolist())
    assert u.issubset({0.0, 1.0, 0, 1}), f"{name}: e not binary, got {u}"

_check_shapes(X_tr, t_tr, e_tr, "train")
_check_shapes(X_val, t_val, e_val, "val")
_check_shapes(X_test, t_test, e_test, "test")

print("Event rate train:", float(np.mean(e_tr)))
print("Event rate val  :", float(np.mean(e_val)))
print("Event rate test :", float(np.mean(e_test)))
# Out:
# Event rate train: 0.14792899787425995
# Event rate val  : 0.1428571492433548
# Event rate test : 0.10679611563682556

# %% [markdown]
# # Cox loss + C index

# %%
def cox_ph_loss(t, e, r, eps=1e-8):
    """
    Negative partial log-likelihood (Breslow) averaged over #events.
    t: times (float)
    e: events (0/1)
    r: risk scores (real-valued), shape (n,1) or (n,)
    """
    t = tf.reshape(t, [-1])
    e = tf.reshape(e, [-1])
    r = tf.reshape(r, [-1])

    # sort by descending time
    order = tf.argsort(t, direction="DESCENDING")
    e = tf.gather(e, order)
    r = tf.gather(r, order)

    # stabilization for exp/log
    r_max = tf.reduce_max(r)
    r_stab = r - r_max

    log_cum_sum_exp = tf.math.log(tf.cumsum(tf.exp(r_stab)) + eps) + r_max
    pll = tf.reduce_sum(e * (r - log_cum_sum_exp))
    n_events = tf.reduce_sum(e) + eps
    return -pll / n_events


def harrell_c_index(t, e, risk):
    """
    Harrell's C-index (numpy).
    risk: higher = higher risk (worse prognosis)
    """
    t = np.asarray(t).reshape(-1)
    e = np.asarray(e).reshape(-1)
    risk = np.asarray(risk).reshape(-1)

    concordant = 0.0
    permissible = 0.0
    ties = 0.0

    n = len(t)
    for i in range(n):
        if e[i] != 1:
            continue
        for j in range(n):
            if t[j] <= t[i]:
                continue
            permissible += 1
            if risk[i] > risk[j]:
                concordant += 1
            elif risk[i] == risk[j]:
                ties += 1

    if permissible == 0:
        return np.nan
    return (concordant + 0.5 * ties) / permissible

# %% [markdown]
# # Builder MLP

# %%
def build_mlp(n_features, hidden=(128, 64), dropout=0.2):
    inputs = keras.Input(shape=(n_features,))
    x = inputs
    for h in hidden:
        x = layers.Dense(h, activation="relu")(x)
        x = layers.Dropout(dropout)(x)
    risk = layers.Dense(1, activation=None)(x)
    return keras.Model(inputs, risk, name="MLP_Cox")

# %% [markdown]
# # Entraînements, early stopping sur C index val

# %%
def train_one_run(
    X_tr, t_tr, e_tr,
    X_val, t_val, e_val,
    lr=1e-3,
    batch_size=128,
    epochs=200,
    patience=20,
    hidden=(128, 64),
    dropout=0.2,
    verbose=0
):
    n_features = X_tr.shape[1]
    model = build_mlp(n_features, hidden=hidden, dropout=dropout)
    optimizer = keras.optimizers.Adam(learning_rate=lr)

    # tf.data
    ds_tr = tf.data.Dataset.from_tensor_slices(
        (X_tr.astype(np.float32), t_tr.astype(np.float32), e_tr.astype(np.float32))
    ).shuffle(len(X_tr), seed=RANDOM_STATE).batch(batch_size)

    # history
    hist = []
    best = {"epoch": None, "val_cindex": -np.inf, "weights": None}

    wait = 0
    for ep in range(1, epochs + 1):
        # ---- train
        tr_losses = []
        for xb, tb, eb in ds_tr:
            with tf.GradientTape() as tape:
                rb = model(xb, training=True)
                loss = cox_ph_loss(tb, eb, rb)
            grads = tape.gradient(loss, model.trainable_weights)
            optimizer.apply_gradients(zip(grads, model.trainable_weights))
            tr_losses.append(float(loss.numpy()))
        tr_loss = float(np.mean(tr_losses))

        # ---- val
        r_val = model(X_val.astype(np.float32), training=False).numpy().reshape(-1)
        val_loss = float(cox_ph_loss(
            tf.constant(t_val.astype(np.float32)),
            tf.constant(e_val.astype(np.float32)),
            tf.constant(r_val.astype(np.float32))
        ).numpy())
        val_c = float(harrell_c_index(t_val, e_val, r_val))

        hist.append({"epoch": ep, "train_loss": tr_loss, "val_loss": val_loss, "val_cindex": val_c, "lr": lr})

        # ---- early stopping on val_cindex
        improved = (val_c > best["val_cindex"])
        if improved:
            best.update({"epoch": ep, "val_cindex": val_c, "weights": model.get_weights()})
            wait = 0
        else:
            wait += 1

        if verbose and (ep % 10 == 0 or ep == 1):
            print(f"ep={ep:03d} tr_loss={tr_loss:.4f} val_loss={val_loss:.4f} val_c={val_c:.4f} (best {best['val_cindex']:.4f})")

        if wait >= patience:
            break

    # restore best
    if best["weights"] is not None:
        model.set_weights(best["weights"])

    df_hist = pd.DataFrame(hist)
    return model, df_hist, best

# %% [markdown]
# # Grid search sur LR (LR sweep)

# %%
lr_grid = [1e-4, 3e-4, 1e-3, 3e-3]
bs_grid = [64, 128, 256]   

runs = []
best_models = {}
hist_by_cfg = {}  

for lr in lr_grid:
    for bs in bs_grid:
        model, df_hist, best = train_one_run(
            X_tr, t_tr, e_tr,
            X_val, t_val, e_val,
            lr=lr,
            batch_size=bs,
            epochs=200,
            patience=20,
            hidden=(128, 64),
            dropout=0.2,
            verbose=0
        )

        runs.append({
            "lr": lr,
            "batch_size": bs,
            "best_epoch": best["epoch"],
            "best_val_cindex": best["val_cindex"],
            "final_epoch_ran": int(df_hist["epoch"].max()),
            "final_val_cindex": float(df_hist.iloc[-1]["val_cindex"]),
        })

        best_models[(lr, bs)] = model
        hist_by_cfg[(lr, bs)] = df_hist

df_runs = pd.DataFrame(runs).sort_values("best_val_cindex", ascending=False)
df_runs.head(10)
# Out:
# 2026-02-03 01:17:01.329178: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:01.890683: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:02.446256: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:03.076941: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:03.528213: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:03.990741: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:04.445580: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:04.943214: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:05.379841: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:05.839999: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:06.797103: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:07.272724: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:07.705492: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:08.163468: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:08.653866: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:09.094305: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:09.539648: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:09.994983: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:10.485333: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:10.957771: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:11.427724: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:11.926127: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:12.484339: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:13.072196: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:13.953211: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:14.619564: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:15.208534: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:15.807681: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:16.383868: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:16.924692: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:17.649273: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:18.269430: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:18.872521: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:19.349058: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:19.864668: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:20.355387: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:20.817205: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:21.341530: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:21.842880: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:22.375923: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:22.937580: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:23.378640: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:23.888032: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:24.374013: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:24.807998: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:25.242605: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:25.770584: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:26.195036: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:26.646485: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:26.969962: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:27.214758: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:27.457595: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:27.918131: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:28.193158: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:28.645963: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:29.096790: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:29.493748: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:29.850595: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:30.094991: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:30.336911: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:30.568178: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:30.804589: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:31.043767: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:31.279168: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:31.513660: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:31.793120: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:32.039421: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:32.272229: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:32.506663: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:32.740489: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:32.973287: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:33.208350: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:33.439494: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:33.671369: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:33.915308: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:34.154564: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:34.386000: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:34.624943: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:34.867260: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:35.120722: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:35.369739: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:35.610516: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:36.093819: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:36.384480: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:36.640924: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:37.404629: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:37.803956: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:38.134410: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:38.462449: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:38.681475: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:38.905897: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:39.120149: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:39.327800: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:39.536522: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:39.750167: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:39.997921: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:40.212372: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:40.419227: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:40.666005: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:40.872932: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:41.081469: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:41.288165: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:41.499793: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:41.710872: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:41.921476: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:42.134583: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:42.339762: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:42.551268: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:42.759554: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:43.011175: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:43.219397: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:43.427817: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:43.640871: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:43.849598: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:44.057666: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:44.265594: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:44.750203: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:44.872339: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:44.991005: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:45.108731: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:45.227354: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:45.343180: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:45.459700: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:45.574947: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:45.693097: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:45.810699: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:45.971674: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:46.107154: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:46.277633: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:46.459060: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:46.584384: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:46.698951: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:46.813684: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:46.947903: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:47.064325: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:47.182499: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:47.297636: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:47.411919: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:47.525413: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:47.639554: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:47.780507: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:47.909195: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:48.040121: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:48.166516: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:48.292392: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:48.413007: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:48.534293: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:48.657219: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:48.780282: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:48.946748: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:49.154028: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:49.329580: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:49.546843: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:49.780250: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:49.957293: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:50.135580: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:50.299803: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:50.564591: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:50.708499: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:50.838937: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:50.954093: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:51.073402: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:51.186111: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:51.348844: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:51.837629: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:52.226493: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:52.700005: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:53.191740: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:53.783776: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:54.221369: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:54.666947: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:55.077492: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:55.471156: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:55.859948: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:56.254675: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:56.711933: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:57.171509: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:57.664861: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:58.141708: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:58.899317: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:59.496809: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:17:59.885243: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:00.300442: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:00.687128: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:01.065519: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:01.640098: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:02.137476: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:02.617688: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:03.081060: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:03.483464: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:03.798639: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:04.040974: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:04.275883: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:04.514001: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:04.740370: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:04.963453: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:05.191023: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:05.415298: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:05.640991: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:05.895552: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:06.108992: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:06.317697: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:06.528691: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:06.739393: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:06.948443: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:07.156523: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:07.368955: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:07.579234: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:07.792808: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:08.001100: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:08.209851: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:08.519818: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:08.925109: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:09.308972: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:09.694494: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:10.067500: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:10.295138: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:10.549014: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:10.801830: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:11.028843: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:11.282058: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:11.542630: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:11.785538: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:12.219333: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:12.593767: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:12.838037: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:13.126421: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:13.429231: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:13.706691: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:13.876568: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:14.032214: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:14.162603: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:14.304622: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:14.499016: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:14.637097: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:14.766563: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:14.892318: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:15.010181: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:15.143076: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:15.295170: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:15.428060: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:15.548824: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:15.664503: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:15.779131: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:15.895736: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:16.208349: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:16.354612: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:16.495262: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:16.619524: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:16.847101: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:17.171776: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:17.344376: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:17.694481: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:17.889971: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:18.063389: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:18.192675: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:18.360834: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:18.558392: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:18.686110: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:18.876823: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:19.002126: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:19.121046: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:19.256036: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:19.372315: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:19.493964: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:19.634323: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:19.763976: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:19.912581: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:20.054294: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:20.198477: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:20.337296: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:20.469219: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:20.610171: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:20.746640: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:20.885152: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:21.010428: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:21.132756: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:21.246901: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:21.369863: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:21.517597: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:21.665744: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:21.815387: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:21.956167: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:22.082104: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:22.197601: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:22.309725: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:22.424965: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:22.548632: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:22.669571: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:23.220166: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:23.619950: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:24.039812: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:24.441715: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:24.852707: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:25.396090: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:25.931549: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:26.339518: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:26.769927: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:27.230036: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:27.633279: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:28.136166: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:28.579676: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:29.016778: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:29.428433: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:29.875018: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:30.305222: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:30.762874: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:31.177525: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:31.832163: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:33.124886: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:33.765962: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:34.614271: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:35.361119: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# ...
# 2026-02-03 01:18:53.607540: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:53.889018: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:54.030753: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:54.153850: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:54.309645: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:54.476991: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:54.601661: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:54.721863: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:54.836008: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:54.948967: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:55.066574: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:55.180942: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:55.298510: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:55.416135: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:55.530204: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:55.644511: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:55.757938: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:55.870879: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:55.983305: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:56.096152: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:56.210161: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:56.345544: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:56.482588: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:56.600245: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:56.714354: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:56.828525: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:56.941550: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:57.054423: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:57.167882: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:57.281542: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:57.395708: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:57.508403: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:57.621703: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:58.069864: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:58.499874: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:58.945538: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:59.434602: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:18:59.869766: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:00.295908: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:00.728619: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:01.121169: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:01.539030: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:01.942744: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:02.367647: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:02.818417: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:03.240991: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:03.628271: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:04.034912: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:04.462063: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:04.886148: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:05.296633: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:05.676718: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:06.055322: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:06.498723: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:06.915398: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:07.264042: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:07.705992: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:08.039597: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:08.279978: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:08.492620: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:08.706805: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:08.915764: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:09.125237: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:09.336973: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:09.544681: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:09.755476: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:09.962794: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:10.176513: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:10.386830: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:10.595430: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:10.807461: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:11.016291: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:11.225102: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:11.433426: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:11.642903: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:11.853472: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:12.036083: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:12.152727: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:12.265609: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:12.378123: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:12.490598: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:12.602751: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:12.716891: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:12.828589: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:12.940821: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:13.052874: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:13.166038: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:13.279279: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:13.393001: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:13.505405: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:13.617683: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:13.731947: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:13.844653: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:13.957013: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:14.070461: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:14.183405: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-02-03 01:19:14.296393: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
#         lr  batch_size  best_epoch  best_val_cindex  final_epoch_ran  \
# 0   0.0001          64          28         0.828141               48
# 5   0.0003         256          41         0.825126               61
# 3   0.0003          64           6         0.791960               26
# 1   0.0001         128          48         0.787940               68
# 8   0.0010         256          15         0.771859               35
# 2   0.0001         256          28         0.739698               48
# 4   0.0003         128          18         0.734673               38
# 10  0.0030         128           1         0.727638               21
# 6   0.0010          64          27         0.726633               47
# 7   0.0010         128           1         0.702513               21
#
#     final_val_cindex
# 0           0.703518
# 5           0.667337
# 3           0.664322
# 1           0.728643
# 8           0.692462
# 2           0.692462
# 4           0.664322
# 10          0.535678
# 6           0.555779
# 7           0.470352

# %% [markdown]
# # Evaluer le meilleur LR sur le test

# %%
best_lr = float(df_runs.iloc[0]["lr"])
best_bs = int(df_runs.iloc[0]["batch_size"])

best_model = best_models[(best_lr, best_bs)]

r_test = best_model(
    X_test.astype(np.float32),
    training=False
).numpy().reshape(-1)

best_hist = hist_by_cfg[(best_lr, best_bs)]
best_epoch = int(df_runs.iloc[0]["best_epoch"])

print("Best lr:", best_lr, "Best batch_size:", best_bs)
print("r_test shape:", r_test.shape)
print("meta_te shape:", meta_te.shape)
# Out:
# Best lr: 0.0001 Best batch_size: 64
# r_test shape: (206,)
# meta_te shape: (206, 91)

# %% [markdown]
# # Graphiqu de la Cox loss sur meilleur LR

# %%
# ---- Figure 1: Cox loss curves (best_lr) ----
plt.figure()
plt.plot(best_hist["epoch"], best_hist["train_loss"], label="Train Cox loss")
plt.plot(best_hist["epoch"], best_hist["val_loss"], label="Val Cox loss")
plt.axvline(best_epoch, linestyle="--", label=f"best epoch = {best_epoch}")
plt.xlabel("Epoch")
plt.ylabel("Cox loss")
plt.title(f"Cox loss baseline (best_lr={best_lr:g}, bs={best_bs})")
plt.legend()
plt.show()

# ---- Figure 2: Validation C-index over epochs (best_lr) ----
plt.figure()
plt.plot(best_hist["epoch"], best_hist["val_cindex"], label="Val C-index")
plt.axvline(best_epoch, linestyle="--", label=f"best epoch = {best_epoch}")
plt.xlabel("Epoch")
plt.ylabel("C-index (Harrell)")
plt.ylim(0, 1)
plt.title(f"Validation C-index baseline (best_lr={best_lr:g}, bs={best_bs})")
plt.legend()
plt.show()

# %%
def harrell_c_index(t, e, risk):
    n = len(t)
    num = 0.0
    den = 0.0
    for i in range(n):
        if e[i] != 1:
            continue
        for j in range(n):
            if t[j] > t[i]:
                den += 1
                if risk[i] > risk[j]:
                    num += 1
                elif risk[i] == risk[j]:
                    num += 0.5
    return num / den if den > 0 else np.nan

# Charger le meilleur modèle sauvegardé
best = keras.models.load_model("best_mlp_cox.keras", compile=False)

# Prédiction du score de risque
risk_test = r_test

# Variables de survie
t_test = meta_te["days_to_last_follow_up"].astype(np.float32).values
e_test = meta_te["event"].astype(np.float32).values

# C-index
cidx = harrell_c_index(t_test, e_test, risk_test)
print("Test C-index (MLP baseline):", cidx)
# Out:
# Test C-index (MLP baseline): 0.6574585635359116

# %% [markdown]
# # Export des données pour analyse biologique

# %%
# ============================================================
# Export des risk scores — MLP BASELINE (TEST uniquement)
# ============================================================

import os
import numpy as np
import pandas as pd

EXPORT_DIR = "./results_risk"
os.makedirs(EXPORT_DIR, exist_ok=True)

RUN_NAME = "MLP_BASELINE_LR_SWEEP_&_BATCH"
ID_COL = "submitter_id"
TIME_COL = "days_to_last_follow_up"
EVENT_COL = "event"

df_test = pd.DataFrame({
    ID_COL: meta_te[ID_COL].astype(str).values,
    "split": "test",
    "risk_score": np.asarray(r_test).reshape(-1),
    "time": meta_te[TIME_COL].astype(float).values,
    "event": meta_te[EVENT_COL].astype(int).values
})

out_path = os.path.join(EXPORT_DIR, f"{RUN_NAME}_risk_test.csv")
df_test.to_csv(out_path, index=False)

# optionnel : risk_all = risk_test (cohérence avec les autres runs)
df_test.to_csv(os.path.join(EXPORT_DIR, f"{RUN_NAME}_risk_all.csv"), index=False)

print("Saved:", out_path)
# Out:
# Saved: ./results_risk/MLP_BASELINE_LR_SWEEP_&_BATCH_risk_test.csv

# %% [markdown]
# # GO enrichment

# %%
# GO ENRICHMENT
# Ce code utilise directement les variables déjà présentes dans le notebook

import os
import numpy as np
import pandas as pd
from scipy.stats import spearmanr
from statsmodels.stats.multitest import multipletests

# ------------------------------------------------------------
# Configuration

RUN_NAME = "MLP_BASELINE_LR_SWEEP_&_BATCH"  #a changer selon notebook

OUTDIR = f"./interpretation_{RUN_NAME}"
os.makedirs(OUTDIR, exist_ok=True)

TOP_N = 300  # Nombre de top gènes
DO_GO = True  

# ------------------------------------------------------------
# 1. Charger les gene names (depuis ton QC)
#

gene_names_path = "./tcga_brca_qc_report/gene_names.npy"

if not os.path.exists(gene_names_path):
    print(f"  Gene names file not found: {gene_names_path}")
    print("Creating gene_names from column names...")
    # Si le fichier n'existe pas, tu peux le créer une fois à partir d'un CSV
    # ou utiliser un placeholder
    gene_names = [f"GENE_{i}" for i in range(X_test.shape[1])]
else:
    gene_names = np.load(gene_names_path, allow_pickle=True).astype(str)

print(f"✓ Loaded {len(gene_names)} gene names")

# ------------------------------------------------------------
# 2. Variables déjà présentes dans le notebook
#
# X_test : déjà chargé (shape: n_samples × n_genes)
# risk_test : déjà calculé par le MLP (shape: n_samples,)
# meta_te : déjà chargé (contient submitter_id)

print(f"✓ X_test shape: {X_test.shape}")
print(f"✓ Risk scores: {len(risk_test)}")
print(f"✓ Meta test: {len(meta_te)}")

# Récupérer les sample IDs
sample_ids = meta_te["submitter_id"].astype(str).values

# -----------------------------------------------------------
# 3. Créer le DataFrame d'expression
#
expr_df = pd.DataFrame(
    X_test,
    index=sample_ids,
    columns=gene_names
)

# --------------------------------------------------------------
# 4. Calculer corrélation Spearman : expression envrion égalle au risk_score
#
print("\n" + "="*60)
print("Calculating gene-risk correlations...")
print("="*60)

rows = []
for i, gene in enumerate(gene_names):
    if i % 1000 == 0:
        print(f"  Progress: {i}/{len(gene_names)} genes...")
    
    gene_expr = expr_df[gene].values
    r, pval = spearmanr(gene_expr, risk_test)
    rows.append((gene, r, pval))

rank_df = pd.DataFrame(rows, columns=["gene", "spearman_r", "pvalue"])
rank_df["abs_r"] = rank_df["spearman_r"].abs()
rank_df["qvalue"] = multipletests(rank_df["pvalue"].values, method="fdr_bh")[1]
rank_df = rank_df.sort_values("abs_r", ascending=False).reset_index(drop=True)

# Sauvegarder le ranking complet
out_rank = os.path.join(OUTDIR, "gene_risk_correlation.csv")
rank_df.to_csv(out_rank, index=False)
print(f"\n✓ Saved full gene ranking: {out_rank}")

# ------------------------------------------------------------
# 5. Top gènes
#
top_genes = rank_df["gene"].head(TOP_N).tolist()
out_top = os.path.join(OUTDIR, f"top_{TOP_N}_genes.txt")
with open(out_top, "w") as f:
    f.write("\n".join(top_genes))

print(f"✓ Saved top {TOP_N} genes: {out_top}")

# Afficher top 10
print(f"\nTop 10 genes correlated with {RUN_NAME} risk score:")
print(f"{'Rank':<6} {'Gene':<15} {'Spearman r':<12} {'P-value':<12} {'Q-value':<12}")
print("-" * 60)
for i, gene in enumerate(top_genes[:10], 1):
    row = rank_df[rank_df["gene"] == gene].iloc[0]
    print(f"{i:<6} {gene:<15} {row['spearman_r']:>+10.4f}  {row['pvalue']:>10.2e}  {row['qvalue']:>10.2e}")

# Statistiques
sig_genes = rank_df[rank_df["qvalue"] < 0.05]
pos_corr = sig_genes[sig_genes["spearman_r"] > 0]
neg_corr = sig_genes[sig_genes["spearman_r"] < 0]

print(f"\nStatistics:")
print(f"  Total genes analyzed: {len(rank_df)}")
print(f"  Significant genes (FDR < 0.05): {len(sig_genes)}")
print(f"    - Positively correlated (high expr → high risk): {len(pos_corr)}")
print(f"    - Negatively correlated (high expr → low risk): {len(neg_corr)}")

# -----------------------------------------------------------
# 6. GO Enrichment
#
if DO_GO:
    try:
        import gseapy as gp
        
        print("\n" + "="*60)
        print("Running GO enrichment...")
        print("="*60)
        
        GO_LIBRARY = "GO_Biological_Process_2021"
        go_outdir = os.path.join(OUTDIR, "go_enrichr")
        os.makedirs(go_outdir, exist_ok=True)
        
        enr = gp.enrichr(
            gene_list=top_genes,  # Les gènes les plus corrélés au risk du MLP
            gene_sets=[GO_LIBRARY],
            organism="Human",
            outdir=go_outdir,
            cutoff=0.05
        )
        
        if hasattr(enr, "results") and enr.results is not None and len(enr.results) > 0:
            out_go = os.path.join(OUTDIR, "go_enrichment.csv")
            enr.results.to_csv(out_go, index=False)
            print(f"\n✓ Saved GO enrichment results: {out_go}")
            print(f"  Found {len(enr.results)} significant GO terms (FDR < 0.05)")
            
            # Top 5 termes
            print("\nTop 5 enriched biological processes:")
            print(f"{'Rank':<6} {'Term':<50} {'P-value':<12} {'Genes'}")
            print("-" * 100)
            for i, row in enr.results.head(5).iterrows():
                term = row['Term'][:47] + "..." if len(row['Term']) > 50 else row['Term']
                genes = row['Genes'][:30] + "..." if len(row['Genes']) > 30 else row['Genes']
                print(f"{i+1:<6} {term:<50} {row['P-value']:>10.2e}  {genes}")
        else:
            print("\n  No significant GO terms found (FDR < 0.05)")
            print("   This might indicate:")
            print("   - Top genes are not part of known pathways")
            print("   - Need to increase TOP_N parameter")
            print("   - Gene names format issue")
            
    except ImportError:
        print("\n  gseapy not installed. Skipping GO enrichment.")
        print("   Install with: pip install gseapy")
    except Exception as e:
        print(f"\n  GO enrichment failed: {e}")
        print("   (Normal if no internet connection)")

# ------------------------------------------------------------
# Summary
#
print("\n" + "="*60)
print(f"✓ Biological interpretation completed for {RUN_NAME}")
print(f"  Results directory: {OUTDIR}")
print(f"  - Gene ranking: gene_risk_correlation.csv")
print(f"  - Top genes: top_{TOP_N}_genes.txt")
if DO_GO:
    print(f"  - GO enrichment: go_enrichment.csv")
print("="*60 + "\n")
# Out:
# ✓ Loaded 10000 gene names
# ✓ X_test shape: (206, 10000)
# ✓ Risk scores: 206
# ✓ Meta test: 206
#
# ============================================================
# Calculating gene-risk correlations...
# ============================================================
#   Progress: 0/10000 genes...
#   Progress: 1000/10000 genes...
#   Progress: 2000/10000 genes...
#   Progress: 3000/10000 genes...
#   Progress: 4000/10000 genes...
#   Progress: 5000/10000 genes...
#   Progress: 6000/10000 genes...
#   Progress: 7000/10000 genes...
#   Progress: 8000/10000 genes...
#   Progress: 9000/10000 genes...
#
# ✓ Saved full gene ranking: ./interpretation_MLP_BASELINE_LR_SWEEP_&_BATCH/gene_risk_correlation.csv
# ✓ Saved top 300 genes: ./interpretation_MLP_BASELINE_LR_SWEEP_&_BATCH/top_300_genes.txt
#
# Top 10 genes correlated with MLP_BASELINE_LR_SWEEP_&_BATCH risk score:
# Rank   Gene            Spearman r   P-value      Q-value
# ------------------------------------------------------------
# 1      DUOX1              +0.3939    4.72e-09    4.72e-05
# 2      HLCS               +0.3777    2.19e-08    1.09e-04
# 3      MCM3AP             +0.3663    6.13e-08    2.04e-04
# 4      ANKRD52            +0.3561    1.49e-07    3.73e-04
# 5      SQLE               +0.3521    2.11e-07    4.08e-04
# 6      RPS15A             -0.3473    3.15e-07    4.08e-04
# 7      RPL34              -0.3466    3.32e-07    4.08e-04
# 8      TRAPPC10           +0.3450    3.81e-07    4.08e-04
# 9      LRP12              +0.3446    3.94e-07    4.08e-04
# 10     KMT2D              +0.3442    4.08e-07    4.08e-04
#
# Statistics:
#   Total genes analyzed: 10000
#   Significant genes (FDR < 0.05): 1160
#     - Positively correlated (high expr → high risk): 962
#     - Negatively correlated (high expr → low risk): 198
#
# ============================================================
# Running GO enrichment...
# ============================================================
#
# ✓ Saved GO enrichment results: ./interpretation_MLP_BASELINE_LR_SWEEP_&_BATCH/go_enrichment.csv
#   Found 1787 significant GO terms (FDR < 0.05)
#
# Top 5 enriched biological processes:
# Rank   Term                                               P-value      Genes
# ----------------------------------------------------------------------------------------------------
# 1      nuclear-transcribed mRNA catabolic process, non...   3.06e-56  RPL5;RPL32;RPL10;RPL31;RPL34;R...
# 2      SRP-dependent cotranslational protein targeting...   8.59e-55  RPL5;RPL32;RPL10;RPL31;RPL34;R...
# 3      cotranslational protein targeting to membrane (...   9.97e-54  RPL5;RPL32;RPL10;RPL31;RPL34;R...
# 4      cytoplasmic translation (GO:0002181)                 3.52e-52  RPL5;RPL32;RPL10;RPL31;RPL34;R...
# 5      protein targeting to ER (GO:0045047)                 1.51e-51  RPL5;RPL32;RPL10;RPL31;RPL34;R...
#
# ============================================================
# ✓ Biological interpretation completed for MLP_BASELINE_LR_SWEEP_&_BATCH
#   Results directory: ./interpretation_MLP_BASELINE_LR_SWEEP_&_BATCH
#   - Gene ranking: gene_risk_correlation.csv
#   - Top genes: top_300_genes.txt
#   - GO enrichment: go_enrichment.csv
# ============================================================
